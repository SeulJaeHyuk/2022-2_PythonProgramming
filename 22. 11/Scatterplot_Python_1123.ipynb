# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,30,20,40]
color = ['red', 'blue', 'yellow', 'green']
size = [100, 300, 200, 600]
plt.rc('font', family='Malgun Gothic') # mac은 AppleGothic / Window는 Malgun Gothic을 사용한다.
plt.title('간단한 산점도 보기')
plt.scatter(x, y, s=size, c=range(4), cmap='rainbow')
print('range =', range)
for i in range(4):
    print(i)
    
plt.colorbar()
plt.xlabel('남자')
plt.ylabel('여자')
plt.show()
# Out:
# range = <class 'range'>
# 0
# 1
# 2
# 3
